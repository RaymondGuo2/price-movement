# %%
import pandas as pd
import yfinance as yf

# %%
# Load SPY data from Yahoo Finance
spy_data = pd.read_csv("../data/raw/yahoo/SPY_2025-09-07.csv")

# %%
spy_data
# Out:
#            Date              Close               High                Low  \
# 0           NaN                SPY                SPY                SPY
# 1    2024-09-06  533.7124633789062   544.814178974002  532.8037981213807
# 2    2024-09-09  539.6881103515625  540.9721661519678   536.004015606287
# 3    2024-09-10   542.038818359375  542.3944354912933  536.6953981658095
# 4    2024-09-11      547.599609375  548.5280480777749  533.3175322402805
# ..          ...                ...                ...                ...
# 246  2025-08-29  645.0499877929688  647.8400268554688  643.1400146484375
# 247  2025-09-02    640.27001953125   640.489990234375  634.9199829101562
# 248  2025-09-03   643.739990234375  644.2100219726562  640.4600219726562
# 249  2025-09-04  649.1199951171875  649.1500244140625   643.510009765625
# 250  2025-09-05   647.239990234375  652.2100219726562  643.3300170898438
#
#                   Open    Volume
# 0                  SPY       SPY
# ...

# %% [markdown]
# In order to have some value, technical indicators are also required alongside the standard OHLCV data, which will be useful for later machine learning activities.
